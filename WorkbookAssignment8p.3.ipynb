# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
Location = r"C:\Users\liamk\Desktop\USF\BUSINESS INTELLIGENCE\datasets\gradedata.csv"
df = pd.read_csv(Location)
plt.scatter(df['grade'], df['hours'])
